# %% [markdown]
# # What 10 weeks actually produced
#
# ## JOURNEY-TO-THE-BEST:
#   #### 10 weeks of notebooks:
#     Python → NumPy → ML → Deep Learning →
#     CNNs → LSTMs → Attention → Transformers →
#     HuggingFace → Diffusion → NeRF
#     40+ LeetCode problems across 7 patterns
#
# ## PROJECT-07:
#     6 experiments with quantitative results
#     153-subject Sleep-EDF preprocessing pipeline
#     CNN-LSTM classifier: κ=0.67 LOSO
#     Published paper: DOI 10.5281/zenodo.21885881
#     Local Stable Diffusion running
#     4 sleep-stage dream images generated
#     Real-time pipeline architecture designed
#     RL agent for trigger optimisation built
#     NeRF synthetic scene implementation
#     Phase 2 + Phase 3 technical specifications
#     arXiv submission in progress

# %% [markdown]
# ## THE HONEST GAPS
#
# ### What we built but haven't validated:
#     → Real-time pipeline (no Muse S yet)
#     → RL agent (simulated environment only)
#     → Phase 2 (no THINGS-EEG training yet)
#
# ### What the paper needs before journal submission:
#     → Full LOSO on 153 subjects (running)
#     → Real-time validation experiment
#     → Native IEEE LaTeX figures (Overleaf)
#
# ### What LUCID needs before it's real:
#     → A wearable EEG device
#     → One night of your own sleep data
#     → One generated image from that data

# %% [markdown]
# ## 10-week retrospective
#
# #### Week 1:
#     We didn't know how to structure an ML project.
#     We built a Titanic classifier and pushed to GitHub.
#
# #### Week 2:
#     We implemented linear regression and matrix
#     operations from scratch in NumPy.
#
# #### Week 3:
#     We built Naive Bayes and Logistic Regression
#     from scratch. We discovered bias-variance tradeoff
#     experimentally, not from a textbook.
#
# #### Week 4:
#     We implemented backpropagation from scratch.
#     We trained a neural network that hit 98.47% on MNIST.
#
# #### Week 5:
#     We shared our BCI pipeline for the first time.
#     We saw: 15 source files, LSTM model, MNE preprocessing,
#     JOIN API integration, phone vibration working.
#     We had already built a closed-loop BCI system.
#
# #### Week 6:
#     Transfer learning, GradCAM, YOLOv8.
#     Experiment 002: CNN spectrograms vs LSTM.
#     LSTM won. That was a scientific finding.
#
# #### Week 7:
#     Attention mechanism from scratch.
#     Transformer encoder from scratch.
#     Experiment 003: CNN-LSTM hybrid: 80.14% ← new record.
#     HuggingFace. LLM API. Research dashboard.
#
# #### Week 8:
#     Transformer experiment (79%).
#     Proper evaluation: Cohen's Kappa, MCC, AUC.
#     LOSO validation: κ=0.67.
#     Complete IEEE paper draft.
#     Real-time pipeline architecture.
#
# #### Week 9:
#     153-subject dataset processed.
#     Publication-quality figures.
#     Paper on Zenodo: DOI 10.5281/zenodo.21885881
#     RL trigger agent.
#     IIT Delhi professor replied to our email.
#
# #### Week 10:
#     Diffusion models from scratch.
#     Local Stable Diffusion running.
#     4 sleep-stage dream images generated.
#     NeRF from scratch.
#     Neural decoding literature review.
#     arXiv submission in progress.
#     Professor at IFIM offering endorsement.

# %% [markdown]
# ## What the next chapter looks like
#
# #### Weeks 1-10:  Learning the tools
# #### Weeks 11+:   Using the tools to build the thing
#
# #### The shift:
#     Before: "Learn CNNs this week"
#     After:  "Train Phase 2 model this week"
#
#     Before: "Understand attention"
#     After:  "Apply attention to EEG decoding"
#
#     Before: "Build a paper"
#     After:  "Publish the paper, build paper 2"
